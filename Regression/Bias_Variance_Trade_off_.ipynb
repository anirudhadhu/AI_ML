# %% [markdown]
# BIAS is the inability of ML model  to truely capture the relation in the training data .

# %% [markdown]
# we should always terget LOW BIAS and LOW VARIANCE.

# %% [markdown]
# To obtain we follow:
#
# 1. Regularization
# 2. Bragging
# 3. Boosting
