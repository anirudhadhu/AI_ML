# %% [markdown]
# # Feature Extraction : PCA

# %% [markdown]
# It is unsupervised machine learning problem and it is complex technique.

# %% [markdown]
# For instance, in a football stadium the surrounding is 3d whereas the photographer and videographer telecast it and we see the same thing in 2d via screens/newspapers or any medium.
#
# Similarly PCA does the same, it try to converts higher dimensional data to lower dimension. It conserves the behavious/ essense.

# %% [markdown]
# Benefits
#
# 1. PCA converts higher dimensional data to lower.
# 2. Faster Execution of algorithm
# 3. Visualization

# %% [markdown]
# # **Note**
#
# Number of principal column <= N ( n is number of features in original data  )

# %% [markdown]
# PCA transform or rotate its axis to get the best possible outcome.

# %% [markdown]
# # Why variance is important ?
#
# Mathematically,
#
# n
#
# E   ((Xi - Xbar) ^2 ) / n
#
# i=1

# %% [markdown]
# We need to mazimize variance.
