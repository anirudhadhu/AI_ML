# %% [markdown]
# Logistic regression is the most important ML algorithm because in deep learning the fundamental building block known as perceptron it hs no more diffrence with logistic regression.

# %% [markdown]
# Perceptron Trick

# %% [markdown]
# Here we randomly start by placing a line and then we implement a loop in loop we select a random point as we ask if the line is performing good or not & if the position is positive then we keep it else the loop continues.
#
# Gennerally the loop can be done 1000 time if the reasult is not satisactory then we can increase it.It is also known as epoch.
#
# the 2nd option is continue the loop till while convergences count how many points are misclassified. Unitil and unless the misclassified points are 0 till then run the loop.

# %% [markdown]
# Transformations

# %% [markdown]
# Ax + By + c = 0
#
# here, if we make the changes in a,b and c the line can be transfromed.
#
# if we make changes in c: increasing / decreasing then the line shift paralelly up and down.
#
# if we make changes in A: The line rotates from the axis (one point)
#
#
# if we make changes in b: The line rotates from the axis (another point)

# %% [markdown]
# https://www.desmos.com/calculator

# %% [markdown]
# Imp:
#
# if we want to shift the line to -ve direction / region then we add in the points where as if we want to shift the line to +ve direction / region then we subract in the points.
#
#
# add and subract by learning rate,
#
# formula = Cof - (learningrate* cordinate)then, we get new coffecient

# %% [markdown]
# Algorithm

# %% [markdown]
# Ax + By + c = 0
#
# its normally written as
#
# W0 = W1x1 + W2X2 = 0
#
# W0 = c, W1=A, W2=B

# %% [markdown]
# ![image.png](data:image/png;base64,...)
